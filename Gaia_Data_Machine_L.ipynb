# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.units import Quantity
from astroquery.gaia import Gaia
from astropy.table import Table
import matplotlib as mpl
import pandas as pd

# %%
 query = """
 SELECT g.source_id, g.ra, g.dec, parallax, parallax_error,
        pmra, pmra_error, pmdec, bp_rp,
        phot_g_mean_mag, phot_g_mean_flux_over_error,
        phot_bp_mean_mag, phot_bp_mean_flux_over_error,
        phot_rp_mean_mag, phot_rp_mean_flux_over_error,
        phot_g_mean_mag + 5.0*log10(parallax/100.0) AS M_G, bp_rp,
        s.ra,s.dec, u_mag, u_mag_error, g_mag, g_mag_error, r_mag, r_mag_error, i_mag, i_mag_error, z_mag, z_mag_error, clean_flag,
        pan.ra,pan.dec,g_mean_psf_mag,g_mean_psf_mag_error,r_mean_psf_mag,r_mean_psf_mag_error,i_mean_psf_mag,i_mean_psf_mag_error,z_mean_psf_mag,z_mean_psf_mag_error,y_mean_psf_mag,y_mean_psf_mag_error,s.sdssdr9_oid

 FROM   gaiadr3.gaia_source AS g, gaiadr1.sdssdr9_original_valid AS s, gaiadr2.sdssdr9_best_neighbour AS xs,
        gaiadr2.panstarrs1_original_valid AS pan, gaiadr3.panstarrs1_best_neighbour AS xpan
 WHERE g.source_id = xs.source_id AND s.sdssdr9_oid = xs.sdssdr9_oid
   AND g.source_id = xpan.source_id AND pan.obj_id = xpan.original_ext_source_id
   AND parallax > 10.0 AND parallax_over_error > 10.0
   AND phot_bp_mean_flux_over_error > 10.0
   AND phot_rp_mean_flux_over_error > 10.0
   AND phot_g_mean_mag + 5.0*log10(parallax/100.0) > (3.333333*(phot_bp_mean_mag - phot_rp_mean_mag) + 8.333333)
   AND (astrometric_sigma5d_max < 1.5 OR (ruwe <= 1.1 AND ipd_gof_harmonic_amplitude < 1))
   AND ((phot_bp_n_obs >2 AND phot_rp_n_obs >2) OR phot_g_mean_mag < 19)
   AND ((astrometric_excess_noise_sig < 2 OR (astrometric_excess_noise_sig >= 2 AND astrometric_excess_noise < 1.5)) OR astrometric_params_solved < 32)
 """

# %%
 query_data = Gaia.launch_job_async(query)
 query_result = query_data.get_results()
 gaia_data = query_result.to_pandas()
 print(gaia_data)
 sdssids = gaia_data['sdssdr9_oid']
 objidstr = ",".join(str(obj_id) for obj_id in sdssids)
 print(objidstr)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
#                 SOURCE_ID          ra        dec    parallax  parallax_error  \
# 0      934814647180364032  121.394370  49.446565   10.002614        0.424442
# 1     3727082704328532480  207.069881  10.639423   10.003681        0.555970
# 2     1543840528716704512  188.371366  48.146928   10.004696        0.447681
# 3      859817100784374144  179.762388  62.032129   10.005049        0.212961
# 4     2492027264515309696   28.566384  -4.446301   10.005247        0.215278
# ...                   ...         ...        ...         ...             ...
# 4209  4235280071072332672  299.119830  -1.045547   86.465801        0.016304
# 4210  3218697767783768320   87.831675  -0.171522   89.112067        0.021058
# 4211  1792830060723673472  325.669790  20.996592   90.545376        0.016760
# 4212  2349916559152267008   10.356220 -22.352334  109.927642        0.020205
# 4213  2552928187080872832   12.296740   5.376557  231.780000        0.018273
#
#              pmra  pmra_error        pmdec     bp_rp  phot_g_mean_mag  ...  \
# 0     -107.222465    0.394659   -47.982219  0.602072        19.735939  ...
# 1     -138.414369    0.750408    19.366113  1.375725        20.090410  ...
# 2     -107.760655    0.252073  -164.682142  1.000086        19.866638  ...
# 3       34.336983    0.212002    26.608492  0.599569        19.335939  ...
# 4       70.403800    0.248606   -76.932469  0.753017        18.926456  ...
# ...           ...         ...          ...       ...              ...  ...
# 4209  -437.759209    0.016009  -706.214639  0.395058        13.591183  ...
# 4210   112.639539    0.020370   226.802776  0.697797        14.425181  ...
# 4211  -224.667171    0.018416  -649.614529  0.233660        13.174672  ...
# 4212  -463.206042    0.021711  -381.783895  0.911183        14.297183  ...
# 4213  1231.399465    0.022947 -2711.882504  0.597588        12.299163  ...
#
#       g_mean_psf_mag_error  r_mean_psf_mag  r_mean_psf_mag_error  \
# 0                 0.018377       19.666300              0.010356
# 1                 0.035106       20.050600              0.017909
# 2                 0.017209       19.808901              0.010247
# 3                 0.017733       19.347099              0.007400
# 4                 0.012319       18.895800              0.010764
# ...                    ...             ...                   ...
# 4209              0.009227       13.648400              0.005526
# 4210                   NaN             NaN                   NaN
# 4211              0.001000       13.510200              0.109127
# 4212              0.001282       14.288400              0.003585
# 4213              0.008268       12.397600              0.001000
#
#       i_mean_psf_mag  i_mean_psf_mag_error  z_mean_psf_mag  \
# 0          19.752300              0.007598       19.869101
# 1          19.767000              0.010027       19.699200
# 2          19.571400              0.013825       19.505899
# 3          19.231501              0.006158       19.237200
# 4          18.816401              0.009378       18.803400
# ...              ...                   ...             ...
# 4209       14.122100              0.075618       13.706300
# 4210       14.321200              0.004189             NaN
# 4211       13.372400              0.001356       13.476600
# 4212       14.111400              0.002333       14.056400
# 4213             NaN                   NaN             NaN
#
#       z_mean_psf_mag_error  y_mean_psf_mag  y_mean_psf_mag_error  sdssdr9_oid
# 0                 0.014721       19.637300              0.003484    410476130
# 1                 0.015858       19.601000              0.038076    163391418
# 2                 0.037096       19.415800              0.026709    405860614
# 3                 0.012241       19.184500              0.042385    449677088
# 4                 0.015369       18.759399              0.029110     40331072
# ...                    ...             ...                   ...          ...
# 4209              0.001198       13.791100              0.002263     59922976
# 4210                   NaN             NaN                   NaN     70565363
# 4211              0.003140       13.573200              0.001246    242169776
# 4212              0.005151       14.032300              0.003364       405507
# 4213                   NaN       12.215000              0.012653    119842014
#
# [4214 rows x 43 columns]
# 410476130,163391418,405860614,449677088,40331072,174083355,395279420,258843760,351048264,353780626,162613052,103532002,202184561,328341279,45144880,71949152,204228354,350844691,289242740,385140437,322613304,203773346,133008714,280784552,37199835,424894013,429025049,24889910,35293489,377856281,178196541,292570163,108543209,423298460,458392629,292063928,263928422,7581870,202383987,296524304,332047157,254825328,277033872,174206239,442166382,190295357,155551387,101022816,395819952,55213541,62520615,466730490,271587553,217457365,223634712,434310279,393064532,403571465,66363706,195775820,250640525,199892319,177515300,243010390,423038364,85578950,319364397,333793293,265981792,7007661,130151863,6366584,66200586,20640740,316066931,187273711,349315682,125162977,274837284,98983200,374238523,131772163,453644059,397280470,150490446,165261356,49215047,303534130,325012206,411133524,124795890,106659962,462078192,254604989,130849350,97303653,467551653,77370251,73257092,181342936,452394190,281894057,299327472,335861316,297784419,349408493,205946507,82825630,220873504,23768442,84003990,280047324,282643296,206155278,400739464,323441453,416002666,251580187,354636402,429841045,164025593,380187249,67680010,414994258,434701161,97090615,238326373,900113,306896398,222407961,32931311,270057788,112391900,223627945,303583487,189494464,160577474,381869055,466710591,32932687,36472563,430963588,163995176,37859369,354558548,80330683,324222999,135133687,311835674,440604592,348783120,319499073,117345929,93115760,90726590,314245347,396501409,194441828,263592640,356570469,130991841,188014109,401087575,793386,170691374,346335842,330153608,6695404,183842126,74198400,260891253,327355351,4711349,6035630,177542069,439043614,274106285,89225667,380687457,144550092,174754013,298438821,627549,247300460,232484088,337604647,376940251,169111412,313530153,41760994,63097135,270584832,24719183,144059110,278386860,40810255,276800906,379084057,155708080,314977886,3973315,410717024,418602024,92907990,285251336,45521477,314418885,156738116,326603902,346673534,297546130,206402372,372866880,447282062,270687347,275565903,35350759,425820579,34862643,356552343,386275663,135741926,192857205,129890233,210349669,75491746,350855957,37679288,316323193,153277581,92861571,39851210,318060639,262960152,458920343,179435610,73150691,222476683,18205188,66293685,135989601,60791512,280329791,382764671,159177515,311637129,434623795,373856281,101065686,278871328,158923693,123138213,274935829,259325318,371004864,92334791,195093424,205241401,167891720,417828317,107132607,30191060,103443915,259364641,363703213,301988322,63946738,448763713,262750577,186812598,270463961,94581554,109636940,311966496,421687114,130936426,79128424,338798964,348021246,267622904,280793514,331865954,41260962,215277784,323373388,401045153,269891723,114112670,460309283,21680602,325089206,53738622,298658483,405863449,295582129,357983146,411356114,319952640,387279800,124784226,333172646,111021372,22524250,337202025,372872105,341146154,311526570,276270341,200217843,21071173,55152382,348942577,331742355,429476869,28937719,350087744,438021391,200090274,462332098,409993899,266948994,160463250,410080935,378753168,409772033,221960102,217656628,24339383,400740935,353257209,394072562,294477884,4637984,417224320,175913726,28611939,373076684,349278755,399980793,360052432,256006076,139057272,262822766,187250022,266461837,266470240,408459275,53531255,209147472,245062881,136763841,410771071,366025955,303764205,284847803,230046104,324342869,218569399,169418960,106928262,145536058,177280570,325707280,59635957,336280355,216495422,50484234,323222828,287484851,228582173,50437841,262002105,348088102,438418984,136793606,265097992,13027932,157428801,440783716,149917852,372303054,263565587,280046631,288676541,210717019,437877905,251460786,410127825,222192067,424211336,257792327,424626242,175861456,156413775,225965272,251488203,360913210,201410383,70894031,203806316,130205210,304500344,369038947,323889628,20761723,393102222,75805097,236130272,221865836,4403 ...

# %%
 gaia_data.to_csv('gaia_query.csv')

# %%
gaia_data = pd.read_csv('gaia_query.csv')
TEST_DATA_Raw = pd.read_csv('TEST_DATA-export (1).csv')

# %%
montreal_df = pd.read_csv('MWDD-export.csv')
DA_raw = pd.read_csv('DA-export (1).csv')
DB_raw = pd.read_csv('DB-export (1).csv')
DC_raw = pd.read_csv('DC-export (1).csv')
DQ_raw = pd.read_csv('DQ-export (1).csv')
DZ_raw = pd.read_csv('DZ-export (1).csv')
DA_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10171 entries, 0 to 10170
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wdid      10171 non-null  object
#  1   teff      10147 non-null  float64
#  2   logL      544 non-null    float64
#  3   parallax  10171 non-null  float64
#  4   Dpc       10171 non-null  float64
#  5   G         10171 non-null  float64
#  6   BP        10170 non-null  float64
#  7   RP        10170 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 635.8+ KB

# %%
# If we used this data for a machine learning model, we would loose a significant amount of our data due to much of the lumenocity being NA
# To see the exact numbers run [DA--DZ]_raw.dropna() and print them.

# %%
DA_fix = DA_raw.drop('logL', axis = 1)
DB_fix = DB_raw.drop('logL', axis = 1)
DC_fix = DC_raw.drop('logL', axis = 1)
DQ_fix = DQ_raw.drop('logL', axis = 1)
DZ_fix = DZ_raw.drop('logL', axis = 1)
TEST_DATA_fix = TEST_DATA_Raw.drop('logL', axis = 1)

# %%
DA_Log_fix= DA_fix.where((DA_fix.parallax > 0))
DB_Log_fix= DB_fix.where((DB_fix.parallax > 0))
DC_Log_fix= DC_fix.where((DC_fix.parallax > 0))
DQ_Log_fix= DQ_fix.where((DQ_fix.parallax > 0))
DZ_Log_fix= DZ_fix.where((DZ_fix.parallax > 0))
TEST_DATA_Log_fix =  TEST_DATA_fix.where((TEST_DATA_Raw.parallax > 0))

DA_fix = DA_Log_fix.dropna()
DB_fix = DB_Log_fix.dropna()
DC_fix = DC_Log_fix.dropna()
DQ_fix = DQ_Log_fix.dropna()
DZ_fix = DZ_Log_fix.dropna()
TEST_DATA_fix = TEST_DATA_Log_fix.dropna()

#DA_Log_fix= DA_fix.where((DA_fix.parallax > 0) & (DA_fix.parallax <= 500))

# %%
#print(DA_Log_fix.to_string())

# %%
plt.hist2d(DA_fix.BP-DA_fix.RP, DA_fix.G + 5.0-5.*np.log10(1000/DA_fix.parallax), bins=100, cmin = 4, norm=mpl.colors.LogNorm(), cmap = 'gist_heat')
plt.ylim(20,10)
plt.xlim(-0.6,2)
plt.figure()
plt.hist2d(DB_fix.BP-DB_fix.RP, DB_fix.G + 5.0-5.*np.log10(1000/DB_fix.parallax), bins=100, cmin = -5, norm=mpl.colors.LogNorm(), cmap = 'gist_heat')
plt.ylim(20,10)
plt.xlim(-0.6,2)
plt.figure()
plt.hist2d(DC_fix.BP-DC_fix.RP, DC_fix.G + 5.0-5.*np.log10(1000/DC_fix.parallax), bins=100, norm=mpl.colors.LogNorm(), cmap = 'gist_heat')
plt.ylim(20,10)
plt.xlim(-0.6,2)
plt.figure()
plt.hist2d(DQ_fix.BP-DQ_fix.RP, DQ_fix.G + 5.0-5.*np.log10(1000/DQ_fix.parallax), bins=100, norm=mpl.colors.LogNorm(), cmap = 'gist_heat')
plt.ylim(20,10)
plt.xlim(-0.6,2)
plt.figure()
plt.hist2d(DZ_fix.BP-DZ_fix.RP, DZ_fix.G + 5.0-5.*np.log10(1000/DZ_fix.parallax), bins=100, norm=mpl.colors.LogNorm(), cmap = 'gist_heat')
plt.ylim(20,10)
plt.xlim(-0.6,2)
plt.figure()

# %%
D_ALL[Absolute_G_mag] =

# %%
plt.scatter(DB_fix.BP-DB_fix.RP, DB_fix.G + 5.0-5.*np.log10(1000/DB_fix.parallax), s=1)
plt.ylim(20,10)
plt.scatter(DC_fix.BP-DC_fix.RP, DC_fix.G + 5.0-5.*np.log10(1000/DC_fix.parallax), s = 1)
plt.ylim(20,10)
plt.scatter(DQ_fix.BP-DQ_fix.RP, DQ_fix.G + 5.0-5.*np.log10(1000/DQ_fix.parallax), s = 1)
plt.scatter(DZ_fix.BP-DZ_fix.RP, DZ_fix.G + 5.0-5.*np.log10(1000/DZ_fix.parallax), c = 'm', s = 1)
plt.figure()
plt.scatter(DB_fix.BP-DB_fix.RP, DB_fix.G + 5.0-5.*np.log10(1000/DB_fix.parallax))
plt.ylim(20,10)
plt.scatter(DQ_fix.BP-DQ_fix.RP, DQ_fix.G + 5.0-5.*np.log10(1000/DQ_fix.parallax))
plt.ylim(20,10)
plt.figure()
plt.scatter(DB_fix.BP-DB_fix.RP, DB_fix.G + 5.0-5.*np.log10(1000/DB_fix.parallax))
plt.ylim(20,10)
plt.scatter(DZ_fix.BP-DZ_fix.RP, DZ_fix.G + 5.0-5.*np.log10(1000/DZ_fix.parallax))
plt.ylim(20,10)
plt.figure()
plt.scatter(DQ_fix.BP-DQ_fix.RP, DQ_fix.G + 5.0-5.*np.log10(1000/DQ_fix.parallax))
plt.ylim(20,10)
plt.scatter(DZ_fix.BP-DZ_fix.RP, DZ_fix.G + 5.0-5.*np.log10(1000/DZ_fix.parallax))
plt.ylim(20,10)
# Out:
# (20.0, 10.0)

# %%
gaia_ra_numpy = gaia_data['ra'].to_numpy()
gaia_dec_numpy = gaia_data['dec'].to_numpy()

# %%
plt.hist2d(TEST_DATA_fix.BP-TEST_DATA_fix.RP, TEST_DATA_fix.G + 5.0-5.*np.log10(1000/TEST_DATA_fix.parallax), bins=400, cmin = 0, norm=mpl.colors.LogNorm(), cmap = 'gist_heat')
plt.ylim(20,0)
# Out:
# (20.0, 0.0)

# %%
plt.hist2d(gaia_data.bp_rp, gaia_data.M_G, bins=150, cmin = 0, norm=mpl.colors.LogNorm(), cmap = 'gist_heat')
plt.ylim(20,10)
plt.figure()
plt.hist(gaia_data.phot_g_mean_mag, bins = 100)
plt.xlim(20,10)
# Out:
# (20.0, 10.0)

# %%
montreal_ra_numpy = montreal_df['icrsra'].to_numpy()
montreal_dec_numpy = montreal_df['icrsdec'].to_numpy()

# %%
coords = SkyCoord(ra=montreal_ra_numpy,dec=montreal_dec_numpy, unit=(u.hourangle,u.deg))

# %%
coords = SkyCoord(ra=montreal_df['icrsra'].to_numpy(),
dec=montreal_df['icrsdec'].to_numpy(), unit=(u.hourangle,u.deg))

# %%
gaia_coords=SkyCoord(ra=gaia_data['ra'].to_numpy()*u.deg,dec=gaia_data['dec'].to_numpy()*u.deg)

# %%
montreal_df['ra_deg'] = coords.ra.deg
montreal_df['dec_deg']= coords.dec.deg

# %%
idx, sep2d,_ = coords.match_to_catalog_sky(gaia_coords)

# %%
max_separation = 1.0*u.arcsec
matches_within_radius = sep2d < max_separation

# %%
matched_gaia = gaia_data.iloc[idx[matches_within_radius]].reset_index(drop=True)
matched_montreal = montreal_df[matches_within_radius].reset_index(drop=True)
